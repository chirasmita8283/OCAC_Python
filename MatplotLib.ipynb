# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.DataFrame({"Length": np.random.randn(700)})
df.head()
# Out:
#      Length
# 0  0.777889
# 1  0.059153
# 2  0.293548
# 3  0.428686
# 4  0.863651

# %%
df['Length'].hist()
plt.show()

# %%
plt.hist(df['Length'])
plt.show()

# %%
plt.hist(df['Length'],bins=20)
plt.show()

# %%
plt.hist(df['Length'], bins=15)
plt.xlabel("Length.")
plt.ylable("Count")
plt.title("Histogram of length")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 plt.hist(df['Length'], bins=15)
#       2 plt.xlabel("Length.")
# ----> 3 plt.ylable("Count")
#       4 plt.title("Histogram of length")
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'

# %%
plt.hist(df['Length'], bins=15)
plt.xlabel('Length.')
plt.ylabel('Count')
plt.title('Histogram of length')
plt.show()

# %%
plt.hist(df['Length'], bins=15, orientation='horizontal')
plt.xlabel('Length in mm.')
plt.ylabel('Count')
plt.title('Histogram of piece length')
plt.show()

# %% [markdown]
# ### Box plot

# %%
plt.boxplot(df['Length'])
plt.show()

# %%
plt.boxplot(df['Length'],notch=True)
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
x=np.arange(1,11)
y=np.arange(11,21)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### Line plot

# %%
plt.plot([11,12,10,1,17,15,14,13])
plt.show()

# %%
plt.plot([11,12,10,1,17,15,14,13],color='green',linewidth=5.0)
plt.title('Chart with user defined color and width of line')
plt.xlabel('X axis')
plt.ylabel('y axis')
plt.show()

# %%
x=np.arange(0,10)
y=np.arange(11,21)
plt.plot(x,y,color='blue',marker='+',linestyle='--',markersize=10)
plt.show()

# %%
x=np.arange(0,10)
y=np.arange(11,21)
plt.plot(x,y,'r*',linestyle='dashed',linewidth=2,markersize=10)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d diagram')
plt. show()

# %%
x= np.linspace(0,2,100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='Cubic')

plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")

plt.legend()
plt.show()

# %%
x=[1,2,3,4,5]
y=[50,51,52,53,44]

plt.subplot(2,2,1)
plt.plot(x,y,'r--')

plt.subplot(2,2,2)
plt.plot(x,y,'g*--')

plt.subplot(2,2,3)
plt.plot(x,y,'bo',linewidth=2,linestyle='dashed')

plt.subplot(2,2,4)
plt.plot(x,y,'go',linestyle='dashed')

plt.show()

# %% [markdown]
# ### Pie Chart

# %%
list=[10,20,23,28,65,87]
lbs=['Facecream','Fasewash','Toothpaste','Bathing soap','Shampoo','Moisturizer']

# %%
plt.pie(list,labels=lbs,autopct='%1.1f%%')
plt.show()

# %%
plt.pie(list,labels=lbs,autopct='%1.1f%%',shadow=True)
plt.axis("equal")
plt.show()

# %%
plt.pie(list,labels=lbs,autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.pie(list,labels=lbs,shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0,0,0.1])
plt.axis("equal")
plt.show()

# %% [markdown]
# # Bar Plot

# %%
marks_scored=[23,45,21,67,89]
roll_no=[11,12,13,14,15]
plt.bar(roll_no, marks_scored)
plt.xlabel('roll no')
plt.ylabel('Marked scored')
plt.show()
